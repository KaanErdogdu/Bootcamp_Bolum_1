# %% [markdown]
# <a href="https://colab.research.google.com/github/KaanErdogdu/Bootcamp_Bolum_1/blob/master/Odev3_4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import statistics
import matplotlib.pyplot as plt
import pandas as pd

# %%
degisken1=np.random.normal(30,5,1000)
degisken2=np.random.normal(60,12,1000)
degisken1.min()
# Out:
# 12.398703391260728

# %%
plt.hist(degisken1)
# Out:
# (array([  2.,   8.,  59., 106., 239., 291., 181.,  77.,  28.,   9.]),
#  array([12.39870339, 15.77028461, 19.14186583, 22.51344705, 25.88502827,
#         29.25660948, 32.6281907 , 35.99977192, 39.37135314, 42.74293436,
#         46.11451558]),
#  <a list of 10 Patch objects>)

# %%
n = 50

ortalama = []
for i in range(1,n):
    a = np.random.randint(degisken1.min(),degisken1.max(),50)
    ortalama.append(np.average(a))
ortalama
# Out:
# [29.86,
#  29.84,
#  30.0,
#  28.76,
#  28.8,
#  28.44,
#  28.48,
#  27.6,
#  26.54,
#  27.66,
#  31.38,
#  30.16,
#  30.22,
#  29.16,
#  28.48,
#  30.16,
#  30.96,
#  29.82,
#  27.86,
#  27.42,
#  27.02,
#  28.44,
#  28.62,
#  27.94,
#  27.52,
#  28.48,
#  29.2,
#  27.84,
#  29.06,
#  29.0,
#  29.04,
#  26.96,
#  29.4,
#  30.54,
#  28.2,
#  27.68,
#  30.34,
#  27.8,
#  28.92,
#  27.96,
#  27.38,
#  27.76,
#  27.64,
#  28.74,
#  26.6,
#  28.88,
#  27.04,
#  27.82,
#  27.88]

# %%
plt.hist(ortalama)
# Out:
# (array([ 4.,  3., 13.,  3.,  9.,  6.,  3.,  5.,  1.,  2.]),
#  array([26.54 , 27.024, 27.508, 27.992, 28.476, 28.96 , 29.444, 29.928,
#         30.412, 30.896, 31.38 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(degisken2)
# Out:
# (array([  4.,  23.,  94., 190., 272., 268., 106.,  33.,   9.,   1.]),
#  array([ 19.16931858,  27.9246714 ,  36.68002422,  45.43537705,
#          54.19072987,  62.9460827 ,  71.70143552,  80.45678834,
#          89.21214117,  97.96749399, 106.72284682]),
#  <a list of 10 Patch objects>)

# %%
n = 1000

ortalama2 = []
for i in range(1,n):
    a2 = np.random.randint(degisken2.min(),degisken2.max(),1000)
    ortalama2.append(np.average(a2))
ortalama2
# Out:
# [61.719,
#  62.114,
#  61.252,
#  60.752,
#  60.891,
#  62.154,
#  62.592,
#  63.161,
#  60.448,
#  61.261,
#  64.352,
#  62.659,
#  60.352,
#  60.894,
#  61.424,
#  62.497,
#  61.825,
#  62.541,
#  61.623,
#  60.778,
#  63.195,
#  62.382,
#  62.281,
#  62.096,
#  62.739,
#  60.885,
#  62.564,
#  62.349,
#  62.69,
#  63.053,
#  61.213,
#  60.915,
#  62.875,
#  61.857,
#  62.185,
#  63.343,
#  63.786,
#  62.549,
#  60.307,
#  61.766,
#  62.002,
#  62.602,
#  63.362,
#  63.269,
#  62.088,
#  61.402,
#  59.53,
#  62.073,
#  62.247,
#  61.924,
#  63.621,
#  62.876,
#  61.88,
#  62.573,
#  61.224,
#  61.178,
#  63.076,
#  63.024,
#  62.191,
#  62.981,
#  60.982,
#  63.562,
#  63.319,
#  60.277,
#  60.995,
#  62.158,
#  62.024,
#  61.619,
#  61.263,
#  63.258,
#  62.63,
#  62.174,
#  61.514,
#  62.879,
#  60.038,
#  62.248,
#  62.481,
#  62.666,
#  63.351,
#  62.346,
#  62.129,
#  62.376,
#  61.274,
#  61.86,
#  61.847,
#  63.277,
#  61.373,
#  61.164,
#  61.007,
#  60.903,
#  61.358,
# ...

# %%
plt.hist(ortalama2)
# Out:
# (array([  4.,  22.,  59., 133., 218., 252., 180.,  91.,  32.,   8.]),
#  array([59.53  , 60.0122, 60.4944, 60.9766, 61.4588, 61.941 , 62.4232,
#         62.9054, 63.3876, 63.8698, 64.352 ]),
#  <a list of 10 Patch objects>)
